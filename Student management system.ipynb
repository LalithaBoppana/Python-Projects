# %%
## students = {
    101: {'name': 'Lalli', 'age': '24', 'course': 'data science'},
    102: {'name': 'Ankith', 'age': '21', 'course': 'python'},
    103: {'name': 'rahul', 'age': '27', 'course': 'data science'},
    104: {'name': 'uday', 'age': '24', 'course': 'ECE'},
}
def add_students():
    student_id = int(input('Enter student ID:'))
    if student_id in students:
        print('Student ID already exists')
        return
    name = input('Enter student name:')
    age = int(input('enter student age:'))
    course = input('Enter student course:')

    students[student_id] = {
        'name': name,
        'age': age,
        'course' : course
    }
    
    print('Student added successfully')

def view_students():
    if not students:
        print('No students found.')
        return
    for id, details in student.items():
        print(f"/nID: {id}")
        print(f"/nName: {details['name']}")
        print(f"/nAge: {details['age']}")
        print(f"/nCourse: {details['course']}")

def search_students():
    student_id = int(input('enter student ID to search:'))
    if student_id in students:
        details = students[student_id]
        print(f"/nName: {details['name']}")
        print(f"/nAge: {details['age']}")
        print(f"/nCourse: {details['course']}")
    else:
        print('Students not found')
def update_students():
    student_id = int(input('enter student ID to update:'))
    if student_id in students:
        name = input('Enter new name:')
        age = int(input('Enter new age:'))
        course = input('Enter new course:')

        students[student_id] = {
            'name': Name,
            'age': age,
            'course': course
        }
        
        print('student updated successfully')

    else:
        print('student not found')

def delete_student():

    student_id = int(input('Enter student ID to delete:'))
    if student_id in students:
        del students[student_id]
        print('students deleted successfully')
    else:
        print('student not found')

while True:
    print('/n-- STUDENT MANAGEMENT SYSTEM -- ')
    print('1. Add Students')
    print('2. View Students')
    print('3. Search Students')
    print('4. Update Students')
    print('5. Delete Student')
    print('6. Exit')
    choice = input('Enetr your choice:')
    if choice == '1':
        add_students()
    elif choice == '2':
        view_students()
    elif choice == '3':
        search_students()
    elif choice == '4':
        update_students()
    elif choice == '5':
        delete_student()
    elif choice == '6':
        print('exit program')
    else:
        print('Inavlid chocie.')
# Out:
# /n-- STUDENT MANAGEMENT SYSTEM --
# 1. Add Students
# 2. View Students
# 3. Search Students
# 4. Update Students
# 5. Delete Student
# 6. Exit
# Enetr your choice: 5
# Enter student ID to delete: 1
# student not found
# /n-- STUDENT MANAGEMENT SYSTEM --
# 1. Add Students
# 2. View Students
# 3. Search Students
# 4. Update Students
# 5. Delete Student
# 6. Exit
# Enetr your choice: 1
# Enter student ID: 101
# Enter student name: lalli
# enter student age: 24
# Enter student course: data science
# Student added successfully
# /n-- STUDENT MANAGEMENT SYSTEM --
# 1. Add Students
# 2. View Students
# 3. Search Students
# 4. Update Students
# 5. Delete Student
# 6. Exit
